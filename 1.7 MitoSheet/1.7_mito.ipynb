# %%
pip install mitosheet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 37.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: ipykernel
# ...

# %%
import mitosheet
mitosheet.sheet(analysis_to_replay="id-ykrjctwzcr")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4baaf28be221> in <cell line: 0>()
# ----> 1 import mitosheet
#       2 mitosheet.sheet(analysis_to_replay="id-ykrjctwzcr")
#
# ModuleNotFoundError: No module named 'mitosheet'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from mitosheet.public.v3 import *; register_analysis("id-ykrjctwzcr");
import pandas as pd

# Imported Sleep_health_and_lifestyle.csv
Sleep_health_and_lifestyle = pd.read_csv(r'Sleep_health_and_lifestyle.csv')

# Pivoted Sleep_health_and_lifestyle into Sleep_health_and_lifestyle_pivot
tmp_df = Sleep_health_and_lifestyle[['Stress Level', 'Occupation', 'Physical Activity Level']].copy()
pivot_table = tmp_df.pivot_table(
    index=['Occupation'],
    columns=['Physical Activity Level'],
    values=['Stress Level'],
    aggfunc={'Stress Level': ['median']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
Sleep_health_and_lifestyle_pivot = pivot_table.reset_index()

# Changed Stress Level to dtype float
Sleep_health_and_lifestyle['Stress Level'] = Sleep_health_and_lifestyle['Stress Level'].astype('float')

# Changed Heart Rate to dtype float
Sleep_health_and_lifestyle['Heart Rate'] = Sleep_health_and_lifestyle['Heart Rate'].astype('float')

# Changed Physical Activity Level to dtype float
Sleep_health_and_lifestyle['Physical Activity Level'] = Sleep_health_and_lifestyle['Physical Activity Level'].astype('float')

# Split Blood Pressure on "/"
Sleep_health_and_lifestyle[['Blood Pressure-split-0-rtr5', 'Blood Pressure-split-1-rtr5']] = Sleep_health_and_lifestyle['Blood Pressure'].str.split('/', n=-1, expand=True, regex=None)
Sleep_health_and_lifestyle = Sleep_health_and_lifestyle[Sleep_health_and_lifestyle.columns[:10].tolist() + ['Blood Pressure-split-0-rtr5', 'Blood Pressure-split-1-rtr5'] + Sleep_health_and_lifestyle.columns[10:-2].tolist()]

# Renamed columns САД, ДАД
Sleep_health_and_lifestyle.rename(columns={'Blood Pressure-split-0-rtr5': 'САД', 'Blood Pressure-split-1-rtr5': 'ДАД'}, inplace=True)

# Changed САД to dtype float
Sleep_health_and_lifestyle['САД'] = to_float_series(Sleep_health_and_lifestyle['САД'])

# Changed ДАД to dtype float
Sleep_health_and_lifestyle['ДАД'] = to_float_series(Sleep_health_and_lifestyle['ДАД'])

# Changed Daily Steps to dtype float
Sleep_health_and_lifestyle['Daily Steps'] = Sleep_health_and_lifestyle['Daily Steps'].astype('float')

# Filled NaN values in 1 columns in Sleep_health_and_lifestyle
Sleep_health_and_lifestyle.fillna({'Sleep Disorder': 'No'}, inplace=True)

# Added column Возраст старше 35
Sleep_health_and_lifestyle.insert(3, 'Возраст старше 35', 0)

# Set formula of Возраст старше 35 at rows {'[0]'}
Sleep_health_and_lifestyle.loc[[0], ['Возраст старше 35']] = IF(Sleep_health_and_lifestyle['Age']>35,1,0)

# Changed Age to dtype float
Sleep_health_and_lifestyle['Age'] = Sleep_health_and_lifestyle['Age'].astype('float')

# Set formula of Возраст старше 35
Sleep_health_and_lifestyle['Возраст старше 35'] = IF(Sleep_health_and_lifestyle['Age']>35,1,0)

# Imported SalesTarget.csv, SalesTarget.csv, SalesTarget.csv, survey.csv
SalesTarget = pd.read_csv(r'C:\\Users\\maksi\\OneDrive\\Desktop\\датасеты\\SalesTarget.csv')
SalesTarget_1 = pd.read_csv(r'C:\\Users\\maksi\\OneDrive\\Desktop\\датасеты\\SalesTarget.csv')
SalesTarget_2 = pd.read_csv(r'C:\\Users\\maksi\\OneDrive\\Desktop\\датасеты\\SalesTarget.csv')
survey = pd.read_csv(r'C:\\Users\\maksi\\OneDrive\\Desktop\\датасеты\\survey.csv')

# Changed Timestamp to dtype datetime
survey['Timestamp'] = pd.to_datetime(survey['Timestamp'], format='%Y-%m-%d  %H:%M:%S', errors='coerce')

# Changed Order Date to dtype datetime
SalesTarget['Order Date'] = pd.to_datetime(SalesTarget['Order Date'], format='%Y-%m-%d', errors='coerce')

# Concatenated 2 into dataframes into df_concat
df_concat = pd.concat([SalesTarget, survey], join='outer', ignore_index=True)

# Renamed columns Order Date
survey.rename(columns={'Timestamp': 'Order Date'}, inplace=True)

# Concatenated 2 into dataframes into df_concat
df_concat = pd.concat([SalesTarget, survey], join='outer', ignore_index=True)

# %%
# Imported SalesTarget.csv, SalesTarget.csv, SalesTarget.csv, survey.csv
SalesTarget = pd.read_csv(r'C:\\Users\\maksi\\OneDrive\\Desktop\\датасеты\\SalesTarget.csv')
SalesTarget_1 = pd.read_csv(r'C:\\Users\\maksi\\OneDrive\\Desktop\\датасеты\\SalesTarget.csv')
SalesTarget_2 = pd.read_csv(r'C:\\Users\\maksi\\OneDrive\\Desktop\\датасеты\\SalesTarget.csv')
survey = pd.read_csv(r'C:\\Users\\maksi\\OneDrive\\Desktop\\датасеты\\survey.csv')

# Changed Timestamp to dtype datetime
survey['Timestamp'] = pd.to_datetime(survey['Timestamp'], format='%Y-%m-%d  %H:%M:%S', errors='coerce')

# Changed Order Date to dtype datetime
SalesTarget['Order Date'] = pd.to_datetime(SalesTarget['Order Date'], format='%Y-%m-%d', errors='coerce')

# Concatenated 2 into dataframes into df_concat
df_concat = pd.concat([SalesTarget, survey], join='outer', ignore_index=True)

# Renamed columns Order Date
survey.rename(columns={'Timestamp': 'Order Date'}, inplace=True)

# Concatenated 2 into dataframes into df_concat
df_concat = pd.concat([SalesTarget, survey], join='outer', ignore_index=True)

# Merged SalesTarget and survey into df_merge
df_merge = SalesTarget.merge(survey[['Order Date']], left_on=['Order Date'], right_on=['Order Date'], how="left", indicator=True, suffixes=(None, "_y"))
df_merge = df_merge[df_merge["_merge"] == "left_only"].drop(columns="_merge")[SalesTarget.columns].reset_index(drop=True)
